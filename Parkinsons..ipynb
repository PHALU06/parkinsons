# %%
import pandas as pd

# %%
#df =pd.read_csv(r"C:\Users\PHALGUNI\Downloads\parkinsons2.csv")
df =pd.read_csv("C:/Users/PHALGUNI/Downloads/parkinsons2.csv")

# %%
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
df.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1',
#        'spread2', 'D2', 'PPE', 'status'],
#       dtype='object')

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1   spread2  \
# ...

# %%
df.dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# status                int64
# dtype: object

# %%
df.nunique
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
df.isnull().sum()
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
#df = df.select_dtypes(exclude=['object'])
df.dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# status                int64
# dtype: object

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %% [markdown]
# df.info()

# %%
df.shape
# Out:
# (195, 23)

# %% [markdown]
# # NORMALISATION

# %%
'''from sklearn import preprocessing
x = df.values #returns a numpy 
StandardScaler = preprocessing.StandardScaler()
x_scaled = StandardScaler.fit_transform(x)
df = pd.DataFrame(x_scaled,columns=df.columns)
df'''
# Out:
# 'from sklearn import preprocessing\nx = df.values #returns a numpy \nStandardScaler = preprocessing.StandardScaler()\nx_scaled = StandardScaler.fit_transform(x)\ndf = pd.DataFrame(x_scaled,columns=df.columns)\ndf'

# %%
from sklearn import preprocessing
x = df.values #returns a numpy 
MinMaxScaler = preprocessing.MinMaxScaler()
x_scaled =MinMaxScaler.fit_transform(x)
df = pd.DataFrame(x_scaled,columns=df.columns)
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0       0.184308      0.112592      0.054815        0.195680
# 1       0.198327      0.094930      0.278323        0.254130
# 2       0.165039      0.059128      0.265288        0.280178
# 3       0.165004      0.072927      0.264200        0.263342
# 4       0.161150      0.080909      0.260107        0.354511
# ..           ...           ...           ...             ...
# 190     0.499820      0.262986      0.165722        0.092440
# 191     0.705488      0.307974      0.138243        0.125794
# 192     0.502730      0.281413      0.050727        0.378653
# 193     0.642893      0.601807      0.054279        0.181703
# 194     0.733274      0.322794      0.071948        0.126747
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0            0.249012  0.145472  0.247588    0.145288      0.312215
# 1            0.288538  0.191233  0.323687    0.191042      0.472887
# ...

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean      0.383623      0.193841      0.292748        0.144233
# std       0.240959      0.186761      0.250564        0.154007
# min       0.000000      0.000000      0.000000        0.000000
# 25%       0.170220      0.066786      0.108323        0.056544
# 50%       0.351961      0.150411      0.223606        0.103558
# 75%       0.549775      0.249162      0.429160        0.180591
# max       1.000000      1.000000      1.000000        1.000000
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.146083    0.126513    0.135389    0.126504      0.184126
# std            0.137636    0.142956    0.147855    0.142934      0.172147
# min            0.000000    0.000000    0.000000    0.000000      0.000000
# ...

# %% [markdown]
# # DATA VISUALISATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df[["MDVP:Jitter(Abs)"]].hist()
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0       0.184308      0.112592      0.054815        0.195680
# 1       0.198327      0.094930      0.278323        0.254130
# 2       0.165039      0.059128      0.265288        0.280178
# 3       0.165004      0.072927      0.264200        0.263342
# 4       0.161150      0.080909      0.260107        0.354511
# ..           ...           ...           ...             ...
# 190     0.499820      0.262986      0.165722        0.092440
# 191     0.705488      0.307974      0.138243        0.125794
# 192     0.502730      0.281413      0.050727        0.378653
# 193     0.642893      0.601807      0.054279        0.181703
# 194     0.733274      0.322794      0.071948        0.126747
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0            0.249012  0.145472  0.247588    0.145288      0.312215
# 1            0.288538  0.191233  0.323687    0.191042      0.472887
# ...

# %%
df[["MDVP:Fo(Hz)"]].hist()
# Out:
# array([[<AxesSubplot:title={'center':'MDVP:Fo(Hz)'}>]], dtype=object)

# %%
df['MDVP:RAP'].value_counts().plot.pie()#has both -ve and +ve values
# Out:
# <AxesSubplot:ylabel='MDVP:RAP'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16, 19))
for i, col in enumerate(df.columns,1):  
    plt.subplot(10,3, i)
    plt.boxplot(df[col])
    plt.xlabel(col)
plt.tight_layout()

# %%
import seaborn as sb
sb.violinplot(x = "NHR", data=df)
plt.show()

# %%
df.plot.scatter(x="DFA",y="HNR")
# Out:
# <AxesSubplot:xlabel='DFA', ylabel='HNR'>

# %% [markdown]
# # OUTLIER

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean      0.383623      0.193841      0.292748        0.144233
# std       0.240959      0.186761      0.250564        0.154007
# min       0.000000      0.000000      0.000000        0.000000
# 25%       0.170220      0.066786      0.108323        0.056544
# 50%       0.351961      0.150411      0.223606        0.103558
# 75%       0.549775      0.249162      0.429160        0.180591
# max       1.000000      1.000000      1.000000        1.000000
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.146083    0.126513    0.135389    0.126504      0.184126
# std            0.137636    0.142956    0.147855    0.142934      0.172147
# min            0.000000    0.000000    0.000000    0.000000      0.000000
# ...

# %%
Y = df.loc[:,'RPDE']
X = df.drop(['RPDE'],axis=1)

# %%
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0       0.184308      0.112592      0.054815        0.195680
# 1       0.198327      0.094930      0.278323        0.254130
# 2       0.165039      0.059128      0.265288        0.280178
# 3       0.165004      0.072927      0.264200        0.263342
# 4       0.161150      0.080909      0.260107        0.354511
# ..           ...           ...           ...             ...
# 190     0.499820      0.262986      0.165722        0.092440
# 191     0.705488      0.307974      0.138243        0.125794
# 192     0.502730      0.281413      0.050727        0.378653
# 193     0.642893      0.601807      0.054279        0.181703
# 194     0.733274      0.322794      0.071948        0.126747
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0            0.249012  0.145472  0.247588    0.145288      0.312215
# 1            0.288538  0.191233  0.323687    0.191042      0.472887
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.50, random_state=7)

# %%
from scipy import stats
def remove_outliers_zscore(X_train,Y_train):
    for col in X_train.columns:
        # print("Before removing col=",col," shape is ", X_train.shape)
        idx = X_train.index[abs(stats.zscore(X_train[col])) <= 3]
        X_train =  X_train.loc[idx]
        Y_train = Y_train.loc[idx]
        print("After col=",col," shape is ", X_train.shape)
    return X_train,Y_train

# %%
def impute_outliers_zscore(X_train,Y_train):
    from scipy.stats import zscore
    for col in X_train.columns:   
        X_train[col] = zscore(X_train[col])
        X_train.loc[X_train[col] > 3, col] = 3
        X_train.loc[X_train[col] < -3, col] = -3
    return X_train,Y_train

# %%
X_train_impute,Y_train_impute = impute_outliers_zscore(X_train.copy(),Y_train.copy())

# %%
id(X_train),id(X_train_impute)
# Out:
# (1816711974976, 1816711976368)

# %%
X_train_z, Y_train_z = remove_outliers_zscore(X_train.copy(),Y_train.copy())
# Out:
# After col= MDVP:Fo(Hz)  shape is  (97, 22)
# After col= MDVP:Fhi(Hz)  shape is  (94, 22)
# After col= MDVP:Flo(Hz)  shape is  (94, 22)
# After col= MDVP:Jitter(%)  shape is  (91, 22)
# After col= MDVP:Jitter(Abs)  shape is  (90, 22)
# After col= MDVP:RAP  shape is  (89, 22)
# After col= MDVP:PPQ  shape is  (88, 22)
# After col= Jitter:DDP  shape is  (88, 22)
# After col= MDVP:Shimmer  shape is  (88, 22)
# After col= MDVP:Shimmer(dB)  shape is  (88, 22)
# After col= Shimmer:APQ3  shape is  (87, 22)
# After col= Shimmer:APQ5  shape is  (86, 22)
# After col= MDVP:APQ  shape is  (86, 22)
# After col= Shimmer:DDA  shape is  (86, 22)
# After col= NHR  shape is  (83, 22)
# After col= HNR  shape is  (83, 22)
# After col= DFA  shape is  (83, 22)
# After col= spread1  shape is  (83, 22)
# After col= spread2  shape is  (83, 22)
# After col= D2  shape is  (83, 22)
# After col= PPE  shape is  (83, 22)
# After col= status  shape is  (83, 22)

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
def rmse_metric(actual, predicted):
    sum_error = 0.0
    for i in range(len(actual)):
        prediction_error = actual[i] - predicted[i]
        sum_error += (prediction_error ** 2)
    mean_error = sum_error / float(len(actual))
    return sqrt(mean_error)

# %%
def coefficients(dataset): 
    x = [row[0] for row in dataset]
    y = [row[1] for row in dataset]
    x_mean, y_mean = mean(x), mean(y)

# %%
# Simple linear regression algorithm
def simple_linear_regression(train, test):
    predictions = list()
    b0, b1 = coefficients(train)
    print("Coefficients after Training are b0 =", b0, " b1=", b1)
    for row in test:
        yhat = b0 + b1 * row[0] # Calculate the prediction
        predictions.append(yhat)
    return predictions

# %%
def rmse_metric(actual, predicted):
    sum_error = 0.0
    for i in range(len(actual)):
        prediction_error = actual[i] - predicted[i]
        sum_error += (prediction_error ** 2)
    mean_error = sum_error / float(len(actual))
    return sqrt(mean_error)

# %%
# Evaluate regression algorithm on training dataset
def evaluate_algorithm(dataset, algorithm):
    test_set = list()
    for row in dataset:
        row_copy = list(row)
        row_copy[-1] = None
        test_set.append(row_copy)
    predicted = algorithm(dataset, test_set)
    actual = [row[-1] for row in dataset]
    for i in range(len(dataset)):
      print("Input Value (x1) is ", dataset[i][0])
      print("Predicted Values is ::",predicted[i])
    rmse = rmse_metric(actual, predicted)
    return rmse

# %%
#

# %%
#

# %%
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0       0.184308      0.112592      0.054815        0.195680
# 1       0.198327      0.094930      0.278323        0.254130
# 2       0.165039      0.059128      0.265288        0.280178
# 3       0.165004      0.072927      0.264200        0.263342
# 4       0.161150      0.080909      0.260107        0.354511
# ..           ...           ...           ...             ...
# 190     0.499820      0.262986      0.165722        0.092440
# 191     0.705488      0.307974      0.138243        0.125794
# 192     0.502730      0.281413      0.050727        0.378653
# 193     0.642893      0.601807      0.054279        0.181703
# 194     0.733274      0.322794      0.071948        0.126747
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0            0.249012  0.145472  0.247588    0.145288      0.312215
# 1            0.288538  0.191233  0.323687    0.191042      0.472887
# ...

# %%
from math import sqrt

# %%
# Calculate the mean value of a list of numbers
def mean(values):
    return sum(values) / float(len(values))
# Calculate covariance between x and y
def covariance(x, mean_x, y, mean_y):
    covar = 0.0
    for i in range(len(x)):
        covar += (x[i] - mean_x) * (y[i] - mean_y)
    return covar
# Calculate the variance of a list of numbers
def variance(values, mean):
    return sum([(x - mean)**2 for x in values])

# %%
reg = LinearRegression().fit(X_train, Y_train) #we have to fit the data in the formula

# %%
#fit transform , we transform the data that we fit algo and formula both are used

# %%
reg.coef_, reg.intercept_
# Out:
# (array([-1.48221776e-01,  6.67727873e-02, -8.31513181e-02, -2.08364704e+00,
#          5.47912640e-01,  1.24955666e+02,  2.28611500e-01, -1.23752823e+02,
#          2.12899057e+00, -1.67215633e+00,  3.24828593e+02, -1.17695698e+00,
#          1.19622629e+00, -3.25378478e+02,  1.99402537e-03, -1.13119687e+00,
#         -2.96536499e-01,  4.62158920e-02,  3.65665616e-01, -4.33179492e-01,
#          2.26077193e-01, -7.58073188e-02]),
#  1.483892783655103)

# %%
Y_pred = reg.predict(X_test)

# %%
Y_pred
# Out:
# array([0.53086577, 0.47393174, 0.41361477, 0.5624443 , 0.48560422,
#        1.03537077, 0.2882931 , 0.83519929, 0.83862578, 0.65144398,
#        0.31297937, 0.57546912, 0.80216414, 0.78490267, 0.38161512,
#        0.58171078, 0.43128614, 0.38666872, 0.5945907 , 0.7393345 ,
#        0.82900589, 0.68038725, 0.41458976, 0.97908723, 0.95661842,
#        0.59664703, 0.51272304, 0.48137414, 0.60445035, 0.71371563,
#        0.68862909, 0.54885931, 0.44785105, 0.67724073, 0.53113925,
#        0.42320448, 0.73765318, 0.2563272 , 0.72419736, 0.4124278 ,
#        0.22300625, 0.82736694, 0.08484716, 0.58631059, 0.27178612,
#        0.57724495, 0.39728343, 0.47415203, 0.85644757, 0.56456163,
#        0.89004566, 0.23959587, 0.5116837 , 0.71302882, 0.71794551,
#        1.00420999, 0.90746635, 0.31175012, 0.34338929, 0.25492016,
#        0.61115944, 0.51059491, 0.10491949, 0.57092208, 0.4672528 ,
#        0.79946906, 0.47723844, 0.93913809, 0.37841751, 0.45921443,
# ...

# %%
rmse_metric(Y_test.values,Y_pred)
# Out:
# 0.14650022432207851

# %%
res = pd.DataFrame([Y_pred,Y_test])
res = res.T
res.columns = ['Y_pred','Y_test']
res[['Y_pred', 'Y_test']].plot()
# Out:
# <AxesSubplot:>

# %%
res[['Y_pred', 'Y_test']]
# Out:
#       Y_pred    Y_test
# 0   0.530866  0.408567
# 1   0.473932  0.539422
# 2   0.413615  0.329849
# 3   0.562444  0.537047
# 4   0.485604  0.404416
# ..       ...       ...
# 93  0.825159  1.000000
# 94  0.665542  0.844865
# 95  0.739743  0.837604
# 96  0.680781  0.867351
# 97  0.639113  0.788222
#
# [98 rows x 2 columns]
